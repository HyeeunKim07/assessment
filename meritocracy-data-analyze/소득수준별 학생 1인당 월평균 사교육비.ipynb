# %% [markdown]
# # 소득수준별 학생 1인당 월평균 사교육비
# values1 = 200만원 미만
# values2 = 400-500만원 미만
# values3 = 800만원 이상

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic'
matplotlib.rcParams['font.size'] = 15
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
labels = ['2017', '2018', '2019', '2020', '2021', '2022']
values1 = [9.3, 9.9, 10.4, 10.3, 11.6, 12.4]
values2 = [27.4, 27.9, 30.0, 26.9, 33.2, 35.1]
values3 = [48.3, 50.5, 53.9, 52.6, 59.3, 64.8]

plt.plot(labels, values1)
plt.plot(labels, values2)
plt.plot(labels, values3)
plt.ylim(5, 70)
# Out:
# (5.0, 70.0)
