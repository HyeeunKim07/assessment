# %% [markdown]
# # 2019년 2학기 소득구간별 국장 신청 및 수혜 인원

# %% [markdown]
# # 전체 대학 신청 인원

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic'
matplotlib.rcParams['font.size'] = 10
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
labels = ['기초', '차상위', '1구간', '2구간', '3구간', '4구간', '5구간', '6구간', '7구간', '8구간', '9구간', '10구간']
values = [49042, 47445, 137956, 107992, 111213, 99990, 47606, 138509, 78191, 170937, 135292, 131385]

plt.bar(labels, values)
plt.ylim(40000, 200000)
# Out:
# (40000.0, 200000.0)

# %% [markdown]
# # 서울 소재 대학 신청 인원

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic'
matplotlib.rcParams['font.size'] = 10
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
labels = ['기초', '차상위', '1구간', '2구간', '3구간', '4구간', '5구간', '6구간', '7구간', '8구간', '9구간', '10구간']
values = [8707, 10354, 31176, 22396, 23061, 20880, 9871, 28122, 15927, 34785, 27425, 33373]

plt.bar(labels, values)
plt.ylim(5000, 40000)
# Out:
# (5000.0, 40000.0)

# %% [markdown]
# # SKY 대학 신청 인원

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic'
matplotlib.rcParams['font.size'] = 10
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
labels = ['기초', '차상위', '1구간', '2구간', '3구간', '4구간', '5구간', '6구간', '7구간', '8구간', '9구간', '10구간']
values = [619, 680, 1816, 1326, 1268, 1219, 600, 1767, 1134, 2934, 2843, 5569]

plt.bar(labels, values)
plt.ylim(500, 6000)
# Out:
# (500.0, 6000.0)
